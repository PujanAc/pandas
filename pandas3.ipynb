# %%
import numpy as np;
import pandas as pd

# %%
students=[

    [3,2,5],
    [1,2,3]




]
st=pd.DataFrame(students,columns=['sc','tr','ds'  ])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-a747fb8f3c9d> in <cell line: 0>()
#       8
#       9 ]
# ---> 10 st=pd.DataFrame(students,columns=['sc','tr','ds'  ],index=['hari','sandip','ram'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     857                         dtype,
#     858                     )
# --> 859                     mgr = arrays_to_mgr(
#     860                         arrays,
#     861                         columns,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117
#     118         # don't force copy because getting jammed in an ndarray anyway
# --> 119         arrays, refs = _homogenize(arrays, index, dtype)
# ...

# %%
movies=pd.read_csv('/content/movies.csv')
matchs=pd.read_csv('/content/ipl-matches.csv')
# Out:
# (950, 20)

# %%
#shape will provide total rows and cls
movies.shape
# Out:
# (1629, 18)

# %%
#indexs
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
#colums returns array of cols

movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
#movies.values
matchs.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
#head and tail
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
#sample
matchs.sample(3)
# Out:
#           ID       City        Date Season MatchNumber                  Team1  \
# 346  1082617    Kolkata  2017-04-23   2017          27  Kolkata Knight Riders
# 215  1178413  Hyderabad  2019-04-21   2019          38  Kolkata Knight Riders
# 636   548373  Hyderabad  2012-05-18   2012          68        Deccan Chargers
#
#                            Team2                                      Venue  \
# 346  Royal Challengers Bangalore                               Eden Gardens
# 215          Sunrisers Hyderabad         Rajiv Gandhi International Stadium
# 636             Rajasthan Royals  Rajiv Gandhi International Stadium, Uppal
#
#                       TossWinner TossDecision SuperOver  \
# 346  Royal Challengers Bangalore        field         N
# 215          Sunrisers Hyderabad        field         N
# 636             Rajasthan Royals          bat         N
#
#                WinningTeam    WonBy  Margin method  Player_of_Match  \
# ...

# %%
#info will provide overall info
matchs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#describe will provide certain calc in mumerical cols
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
#null
tr=movies.isnull()
tr.sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#isduplicated is used to check if row is duplicated
matchs.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %%
##rename is used to change name of cols
#it is not permanant change if u want to make it permanent use inplace =true
st.rename(columns={
    'sc':"science"
})
# Out:
#    science  tr  ds
# 0        3   2   5
# 1        1   2   3

# %% [markdown]
# m

# %% [markdown]
# Math mathical func

# %%
#sum
st.sum(axis=0)
st.mean()
# Out:
# sc    2.0
# tr    2.0
# ds    4.0
# dtype: float64

# %%
##selection cols from data frame
matchs['City']
# Out:
# 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object

# %%
##selecting multiple cols, use fancy indexing
movies[['title_x',"year_of_release",'actors']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
#fetching rows
#iloc use index to fetch whiile loc uses lable
matchs.iloc[1:3]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
#using fancy index
movies.iloc[[0,122]]
# Out:
#                       title_x    imdb_id  \
# 0    Uri: The Surgical Strike  tt8291224
# 122          Gold (2018 film)  tt6173990
#
#                                            poster_path  \
# 0    https://upload.wikimedia.org/wikipedia/en/thum...
# 122  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link  \
# 0    https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 122     https://en.wikipedia.org/wiki/Gold_(2018_film)
#
#                       title_y            original_title  is_adult  \
# 0    Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 122                      Gold                      Gold         0
#
#      year_of_release runtime               genres  imdb_rating  imdb_votes  \
# 0               2019     138     Action|Drama|War          8.4       35112
# 122             2018     151  Drama|History|Sport          7.3       10081
#
#                                                  story  \
# ...

# %%
##sets new index
matchs.set_index('City',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-e5b331956a7b> in <cell line: 0>()
#       1 ##sets new index
# ----> 2 matchs.set_index('City',inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['City'] are in the columns"

# %%
matchs.loc[['Mumbai','Delhi']]
## you can do iloc[a:b:2]
matchs.iloc[0]
# Out:
# ID                                                           1312200
# Date                                                      2022-05-29
# Season                                                          2022
# MatchNumber                                                    Final
# Team1                                               Rajasthan Royals
# Team2                                                 Gujarat Titans
# Venue                               Narendra Modi Stadium, Ahmedabad
# TossWinner                                          Rajasthan Royals
# TossDecision                                                     bat
# SuperOver                                                          N
# WinningTeam                                           Gujarat Titans
# WonBy                                                        Wickets
# Margin                                                           7.0
# method                                                           NaN
# ...

# %%
#fetching rows with specific cols using loc and iloc
movies.loc[[1,8],['title_x','year_of_release']]
# Out:
#                             title_x  year_of_release
# 1                     Battalion 609             2019
# 8  Manikarnika: The Queen of Jhansi             2019

# %%
matchs.head(8)
# Out:
#                 ID        Date Season  MatchNumber  \
# City
# Ahmedabad  1312200  2022-05-29   2022        Final
# Ahmedabad  1312199  2022-05-27   2022  Qualifier 2
# Kolkata    1312198  2022-05-25   2022   Eliminator
# Kolkata    1312197  2022-05-24   2022  Qualifier 1
# Mumbai     1304116  2022-05-22   2022           70
# Mumbai     1304115  2022-05-21   2022           69
# Mumbai     1304114  2022-05-20   2022           68
# Mumbai     1304113  2022-05-19   2022           67
#
#                                  Team1                        Team2  \
# City
# Ahmedabad             Rajasthan Royals               Gujarat Titans
# Ahmedabad  Royal Challengers Bangalore             Rajasthan Royals
# Kolkata    Royal Challengers Bangalore         Lucknow Super Giants
# Kolkata               Rajasthan Royals               Gujarat Titans
# Mumbai             Sunrisers Hyderabad                 Punjab Kings
# Mumbai                  Delhi Capitals               Mumbai Indians
# ...

# %%
#find final winner
mask1=matchs['MatchNumber']=='Final'
tt=matchs[mask1]['WinningTeam']
tt
# Out:
# City
# Ahmedabad              Gujarat Titans
# Dubai             Chennai Super Kings
# NaN                    Mumbai Indians
# Hyderabad              Mumbai Indians
# Mumbai            Chennai Super Kings
# Hyderabad              Mumbai Indians
# Bangalore         Sunrisers Hyderabad
# Kolkata                Mumbai Indians
# Bangalore       Kolkata Knight Riders
# Kolkata                Mumbai Indians
# Chennai         Kolkata Knight Riders
# Chennai           Chennai Super Kings
# Mumbai            Chennai Super Kings
# Johannesburg          Deccan Chargers
# Mumbai               Rajasthan Royals
# Name: WinningTeam, dtype: object

# %%
tt=matchs['SuperOver']=='Y'
matchs[tt].shape
# Out:
# (14, 19)

# %%
##how many matches csk won in kolkata
mask1=matchs.index=='Kolkata'
mask2=matchs['WinningTeam']=='Chennai Super Kings'
matchs[mask1 & mask2].shape
# Out:
# (5, 19)

# %%
mask=matchs["TossWinner"]==matchs['WinningTeam']
mask.sum()
# Out:
# np.int64(489)

# %%
##valuecounts
matchs['WinningTeam'].value_count()
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Gujarat Titans                  12
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64
